# %%
#other
import os
import importlib
import copy
import numpy as np

from cplap_with_beef import Organizer
importlib.reload(Organizer)

from cplap_with_beef import QE_Helper
importlib.reload(QE_Helper)

from pymatgen.io.ase import AseAtomsAdaptor
from ase.io import read as ase_read

# %%
os.environ['CPLAP_DIR'] = "[specify CPLAP directory]"

os.chdir('[CHANGE TO BEEF_Charged_Defects_REPO]')
beef_charged_defect_dir = os.getcwd()

# %%
#general info
defect = {'C': -1}

#Specific information for each system in test
defect_systems = {
    "C_1x1x1_qn2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.02862336993,
        'relaxation_all':False,
        'charge': -2,
        'atoms': 7,
        'location': 1,
        'FS_correction':0,
        'VBM': 12.9576, #pulled from pristine 1x1x1
        'pristine_min_bond_length': 1.54687,
    },
    "C_1x1x1_qn1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.0373953705,
        'relaxation_all':False,
        'charge': -1,
        'atoms': 7,
        'location': 1,
        'FS_correction':0,
        'VBM': 12.9576,
        'pristine_min_bond_length': 1.54687,
    },
    "C_1x1x1_q0" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.05703541865,
        'relaxation_all':False,
        'charge': 0,
        'atoms': 7,
        'location': 1,
        'FS_correction':0,
        'VBM': 12.9576,
        'pristine_min_bond_length': 1.54687,
    },
    "C_1x1x1_qp1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.07967992412,
        'relaxation_all':False,
        'charge': 1,
        'atoms': 7,
        'location': 1,
        'FS_correction':0,
        'VBM': 12.9576, #pulled from pristine 1x1x1
        'pristine_min_bond_length': 1.54687,
    },
    "C_1x1x1_qp2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex73_1x1x1/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.130395261,
        'relaxation_all':False,
        'charge': 2,
        'atoms': 7,
        'location': 1,
        'FS_correction':0,
        'VBM': 12.9576,
        'pristine_min_bond_length': 1.54687,
    },
    "C_2x2x2_qn2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.03017157611,
        'relaxation_all':False,
        'charge': -2,
        'atoms': 63,
        'location': 1,
        'FS_correction':2.666387554,
        'VBM': 12.9574, #pulled from pristine 2x2x2
        'pristine_min_bond_length': 1.54687,
    },
    "C_2x2x2_qn1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.02771700097,
        'relaxation_all':False,
        'charge': -1,
        'atoms': 63,
        'location': 1,
        'FS_correction':0.8638684573,
        'VBM': 12.9574, #pulled from pristine 2x2x2
        'pristine_min_bond_length': 1.54687,
    },
    "C_2x2x2_q0" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.02812310445,
        'relaxation_all':False,
        'charge': 0,
        'atoms': 63,
        'location': 1,
        'FS_correction': 0,
        'VBM': 12.9574, #pulled from pristine 2x2x2
        'pristine_min_bond_length': 1.54687,
    },
    "C_2x2x2_qp1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.03014834069,
        'relaxation_all':False,
        'charge': 1,
        'atoms': 63,
        'location': 1,
        'FS_correction': 0.07654219973,
        'VBM': 12.9574, #pulled from pristine 2x2x2
        'pristine_min_bond_length': 1.54687,
    },
    "C_2x2x2_qp2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex6_2x2x2/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.03378558766,
        'relaxation_all':False,
        'charge': 2,
        'atoms': 63,
        'location': 1,
        'FS_correction': 1.078660444,
        'VBM': 12.9574, #pulled from pristine 2x2x2
        'pristine_min_bond_length': 1.54687,
    },
    "C_3x3x3_qn2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.03106923146,
        'relaxation_all':False,
        'charge': -2,
        'atoms': 215,
        'location': 1,
        'FS_correction':1.491158238,
        'VBM': 12.9566, #Pulled from 3x3x3 pristine
        'pristine_min_bond_length': 1.54687,
    },
    "C_3x3x3_qn1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.02735850427,
        'relaxation_all':False,
        'charge': -1,
        'atoms': 215,
        'location': 1,
        'FS_correction': 0.4243701936,
        'VBM': 12.9566,
        'pristine_min_bond_length': 1.54687,
    },
    "C_3x3x3_q0" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.02672305349,
        'relaxation_all':False,
        'charge': 0,
        'atoms': 215,
        'location': 1,
        'FS_correction': 0,
        'VBM': 12.9566,
        'pristine_min_bond_length': 1.54687,
    },
    "C_3x3x3_q1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.02922650106,
        'relaxation_all':False,
        'charge': 1,
        'atoms': 215,
        'location': 1,
        'FS_correction': 0.2091689416 , #UPDATE!
        'VBM': 12.9566,
        'pristine_min_bond_length': 1.54687,
    },
    "C_3x3x3_q2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex21_3x3x3/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.03386296604,
        'relaxation_all':False,
        'charge': 2,
        'atoms': 215,
        'location': 1,
        'FS_correction': 1.046733943,
        'VBM': 12.9566,
        'pristine_min_bond_length': 1.54687,
    },
    "C_4x4x4_qn2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.03124355747,
        'relaxation_all':False,
        'charge': -2,
        'atoms': 511,
        'location': 1,
        'FS_correction': 1.042332347,
        'VBM': 12.9574, #Pulled from pristine 4x4x4
        'pristine_min_bond_length': 1.54687,
    },
    "C_4x4x4_qn1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.02746390174,
        'relaxation_all':False,
        'charge': -1,
        'atoms': 511,
        'location': 1,
        'FS_correction': 0.2793570028,
        'VBM': 12.9574, #Update
        'pristine_min_bond_length': 1.54687,
    },
    "C_4x4x4_q0" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.0267061774,
        'relaxation_all':False,
        'charge': 0,
        'atoms': 511,
        'location': 1,
        'FS_correction': 0,
        'VBM': 12.9574, #Update
        'pristine_min_bond_length': 1.54687,
    },
    "C_4x4x4_q1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.02908577619,
        'relaxation_all':False,
        'charge': 1,
        'atoms': 511,
        'location': 1,
        'FS_correction': 0.1986317707,
        'VBM': 12.9574, #Update
        'pristine_min_bond_length': 1.54687,
    },
    "C_4x4x4_q2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex31_4x4x4/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.03307619594,
        'relaxation_all':False,
        'charge': 2,
        'atoms': 511,
        'location': 1,
        'FS_correction': 0.867919859,
        'VBM': 12.9574, #Update
        'pristine_min_bond_length': 1.54687,
    },
    "C_5x5x5_qn2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.03112724540019293,
        'relaxation_all':False,
        'charge': -2,
        'atoms': 999,
        'location': 1,
        'FS_correction':0.7944088744,
        'VBM': 12.9568, #Pulled from 5x5x5 pristine
        'pristine_min_bond_length': 1.54687,
    },
    "C_5x5x5_qn1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.02724406233,
        'relaxation_all':False,
        'charge': -1,
        'atoms': 999,
        'location': 1,
        'FS_correction':0.2054921275,
        'VBM': 12.9568,
        'pristine_min_bond_length': 1.54687,
    },
    "C_5x5x5_q0" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.026644364457791062,
        'relaxation_all':False,
        'charge': 0,
        'atoms': 999,
        'location': 1,
        'FS_correction':0,
        'VBM': 12.9568,
        'pristine_min_bond_length': 1.54687,
    },
    "C_5x5x5_qp1" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.02931242788,
        'relaxation_all':False,
        'charge': 1,
        'atoms': 999,
        'location': 1,
        'FS_correction':0.1749585538,
        'VBM': 12.9568,
        'pristine_min_bond_length': 1.54687,
    },
    "C_5x5x5_qp2" : {
        'defect_name':'V_C',
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/V_C/experiments/ex30_5x5x5/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.03349952801,
        'relaxation_all':False,
        'charge': 2,
        'atoms': 999,
        'location': 1,
        'FS_correction':0.7293404552,
        'VBM': 12.9568,
        'pristine_min_bond_length': 1.54687,
    },
}

# %%
os.chdir(f"{beef_charged_defect_dir}/data_files/V_C/Analysis")

# %%
import copy

#Read through the qe output. Return a dictionary of raw qe info
def read_qe_output(filename):

    result = {
        'job_done':False,
        'total_energy': False,
        'beef_ensemble':False,
        'atom_dict':False,
    }

    #print(f"Searching for {filename}")
    file_found = True
    #print(f"file_found: {file_found}")

    if file_found == True:

        #print(f"The file '{filename}' has been found! Huzzah!")

        job_complete = False
        total_energy_found = False
        total_energy = 0

        line_nums_atoms = [0,0]
        line_nums_beef_ensemble = [0,0]

        unit_type = ""
        ry_to_eV = 13.6057039763


        with open(filename) as file:

            line_count = 0

            line_info_cart_axes = 'Cartesian axes'
            line_info_crystal_axes = 'Crystallographic axes'
            line_info_beef_ens_header = 'BEEFens 2000 ensemble energies'
            line_info_min_energy = '!    total energy'
            line_info_job_done = 'JOB DONE.'

            #Loop through every line in the output file
            for line in file:

                line_count += 1

                #1. Search for minimum energy
                if line_info_min_energy in line:
                    total_energy_found = True

                    unit = line.split(' ')[-1]
                    #self.debug_obj.debug_log(f"Energy unit: {unit}")

                    total_energy = float(line.split(" ")[-2])
                    #self.debug_obj.debug_log(f"Initial energy value: {total_energy}")

                    if "Ry" in unit:
                        #self.debug_obj.debug_log(f"Energy in Ry!")
                        unit_type = "Ry"
                        total_energy = total_energy*ry_to_eV

                #2. Search for jobe done
                if line_info_job_done in line:
                    job_complete = True
                    #print(f"Job complete found!")

                #3. Search for 'Cartesian axes' header
                if line_info_cart_axes in line:
                    line_nums_atoms[0] = line_count + 3

                #4. Search for 'Crystallographic axes' header
                if line_info_crystal_axes in line:
                    line_nums_atoms[1] = line_count - 2

                #5. Search for 'BEEFens 2000 ensemble energies'
                if line_info_beef_ens_header in line:
                    line_nums_beef_ensemble[0] = line_count + 1
                    line_nums_beef_ensemble[1] = line_count + 2000

            if total_energy_found and job_complete:
                result['job_done'] = True
                result['total_energy'] = total_energy
                #print(f"Total energy = {total_energy} eV!")
            else:
                return result

        #print(f"line_nums_atoms: {line_nums_atoms}")
        #print(f"line_nums_beef_ensemble: {line_nums_beef_ensemble}")

        #Now grab the atoms numbers and beef ensemble
        with open(filename) as file:

            line_count = 0

            atom_dict = {}
            beef_ens = []

            for line in file:
                line_count += 1

                if line_nums_atoms[0] <= line_count <= line_nums_atoms[1]:
                    atom_symbol = line.split()[1]
                    if atom_symbol in atom_dict:
                        atom_dict[atom_symbol] += 1
                    else:
                        atom_dict[atom_symbol] = 1

                if line_nums_beef_ensemble[0] <= line_count <= line_nums_beef_ensemble[1]:
                    raw_energy = float(line.split()[0])
                    clean_energy = 0
                    if unit_type == "Ry":
                        clean_energy = raw_energy*ry_to_eV
                    else:
                        clean_energy = raw_energy
                    beef_ens.append(clean_energy)

                if line_count > line_nums_beef_ensemble[1]:
                    break

            result['beef_ensemble'] = copy.deepcopy(beef_ens)
            result['atom_dict'] = copy.deepcopy(atom_dict)

    return result

# %%
# Generate the 2d array of all meaningful data
# Column = optimal,centroid,relaxation,charge,atoms,DFE

chempot_n_i = {}
for key in defect:
    chempot_n_i[key] = defect[key]*-1

#Create 2d arrau
table_order = ['defect_name','beef_idx','optimal','centroid','relaxation','relaxation_all','charge','atoms','atoms_per_side','location','dfe','raw_energy','chem_pot','cube_root_of_volume_wrt_min_bond']

all_data = []

add_optimal = True
add_BEEF = True
experiment_filename = "C_all_data.csv"

for defect_system in defect_systems:

    pristine_result = read_qe_output(defect_systems[defect_system]["pristine_pwo"])
    defect_result = read_qe_output(defect_systems[defect_system]["defect_pwo"])

    pristine_number_of_atoms = pristine_result['atom_dict']['C']
    print(f"pristine number of atoms: {pristine_number_of_atoms}")

    pristine_ase = ase_read(defect_systems[defect_system]["pristine_pwo"])
    pristine_pymatgen = AseAtomsAdaptor.get_structure(atoms = pristine_ase)
    cube_root_of_volume = ((pristine_pymatgen.volume)**(1/3)) #pymat api gives volume in Angstrom^3
    cube_root_of_volume_wrt_min_bond = cube_root_of_volume/(defect_systems[defect_system]['pristine_min_bond_length'])


    entry_template = np.zeros(len(table_order),dtype=object)
    entry_template[table_order.index('defect_name')] = defect_systems[defect_system]['defect_name']
    entry_template[table_order.index('charge')] = defect_systems[defect_system]['charge']
    entry_template[table_order.index('atoms')] = defect_systems[defect_system]['atoms']
    entry_template[table_order.index('atoms_per_side')] = (pristine_number_of_atoms)**(1/3)
    entry_template[table_order.index('location')] = defect_systems[defect_system]['location']
    entry_template[table_order.index('centroid')] = False
    entry_template[table_order.index('optimal')] = False
    entry_template[table_order.index('cube_root_of_volume_wrt_min_bond')] = cube_root_of_volume_wrt_min_bond

    #Relaxation (Angstroms, NOT normalized)
    entry_template[table_order.index('relaxation')] = defect_systems[defect_system]['relaxation']
    if(defect_systems[defect_system]['relaxation_all'] == False):
        entry_template[table_order.index('relaxation_all')] = defect_systems[defect_system]['relaxation']
    else:
        entry_template[table_order.index('relaxation_all')] = defect_systems[defect_system]['relaxation_all']

    if(add_optimal):
        #First iterate through the 'optimal' chemical potential
        new_row = copy.copy(entry_template)
        new_row[table_order.index('optimal')] = True
        new_row[table_order.index('beef_idx')] = 2000


        raw_energy = defect_result['total_energy'] - pristine_result['total_energy']
        fs_correct = defect_systems[defect_system]['FS_correction']
        chem_pot = (pristine_result['total_energy']/pristine_number_of_atoms)
        fermi = (defect_systems[defect_system]['VBM']*defect_systems[defect_system]['charge'])
        dfe = raw_energy + fs_correct + chem_pot + fermi
        print(f"raw_energy: {raw_energy}")
        print(f"fs_correct: {fs_correct}")
        print(f"chem_pot: {chem_pot}")
        print(f"fermi: {fermi}")
        print(f"dfe: {dfe}")

        new_row[table_order.index('dfe')] = dfe
        new_row[table_order.index('centroid')] = True

        all_data.append(new_row)

    if(add_BEEF):
        #Next iterate through the BEEF ensemble
        entry_template[table_order.index('optimal')] = False

        #Next iterate through the BEEF ensemble
        for beef_idx in range(0,2000):
            new_row = copy.copy(entry_template)
            entry_template[table_order.index('beef_idx')] = beef_idx

            pristine_energy = (pristine_result['total_energy'] + pristine_result['beef_ensemble'][beef_idx])
            defect_energy = (defect_result['total_energy'] + defect_result['beef_ensemble'][beef_idx])

            raw_energy = (defect_energy - pristine_energy)
            fs_correct = defect_systems[defect_system]['FS_correction']
            chem_pot = (pristine_energy/pristine_number_of_atoms)
            fermi = (defect_systems[defect_system]['VBM']*defect_systems[defect_system]['charge'])
            dfe = raw_energy + fs_correct + chem_pot + fermi

            new_row[table_order.index('dfe')] = dfe
            new_row[table_order.index('centroid')] = True

            all_data.append(new_row)

os.chdir(f'{beef_charged_defect_dir}/data_files/V_C/Analysis')

import pandas as pd
pd_all_data = pd.DataFrame(all_data)
pd_all_data.columns = table_order
pd_all_data.to_csv(experiment_filename)
# Out:
# pristine number of atoms: 8
# raw_energy: 288.512413156134
# fs_correct: 0
# chem_pot: -258.4100548653074
# fermi: -25.9152
# dfe: 4.187158290826602
# pristine number of atoms: 8
# raw_energy: 275.9841129043127
# fs_correct: 0
# chem_pot: -258.4100548653074
# fermi: -12.9576
# dfe: 4.616458039005309
# pristine number of atoms: 8
# raw_energy: 263.8014767186867
# fs_correct: 0
# chem_pot: -258.4100548653074
# fermi: 0.0
# dfe: 5.391421853379256
# pristine number of atoms: 8
# raw_energy: 252.27214058678032
# fs_correct: 0
# chem_pot: -258.4100548653074
# fermi: 12.9576
# dfe: 6.819685721472908
# pristine number of atoms: 8
# raw_energy: 241.69361009710792
# fs_correct: 0
# chem_pot: -258.4100548653074
# fermi: 25.9152
# dfe: 9.198755231800504
# pristine number of atoms: 64
# raw_energy: 294.29462727399005
# fs_correct: 2.666387554
# chem_pot: -258.4100388360874
# fermi: -25.9148
# dfe: 12.636175991902647
# pristine number of atoms: 64
# raw_energy: 279.4327036154482
# ...
