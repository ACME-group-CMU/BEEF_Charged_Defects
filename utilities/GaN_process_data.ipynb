# %%
#other
import os
import importlib
import copy
import numpy as np

from cplap_with_beef import Organizer
importlib.reload(Organizer)

from cplap_with_beef import QE_Helper
importlib.reload(QE_Helper)

from pymatgen.io.ase import AseAtomsAdaptor
from ase.io import read as ase_read

# %%
os.environ['CPLAP_DIR'] = "[specify CPLAP directory]"

os.chdir('[CHANGE TO BEEF_Charged_Defects_REPO]')
beef_charged_defect_dir = os.getcwd()

# %%
#general info

#Specific information for each system in test
defect_systems = {
    "GaN_SUB_2x2x2_qp0" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/SUB_1/0/espresso.pwo',
        'relaxation': 0.08811559907,
        'relaxation_all': 0.09120608647,
        'charge': 0 ,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_2x2x2_qp1" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/SUB_1/1/espresso.pwo',
        'relaxation': 0.09053393156,
        'relaxation_all': 0.09539663092,
        'charge': 1,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_2x2x2_qp2" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/SUB_1/2/espresso.pwo',
        'relaxation': 0.0918722337,
        'relaxation_all': 0.1001312044,
        'charge': 2,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_2x2x2_qp3" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex65_GaN/supercells/SUB_1/3/espresso.pwo',
        'relaxation': 0.1073227612,
        'relaxation_all': 0.1225766173,
        'charge': 3,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_3x3x2_qp0" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/SUB_1/0/espresso.pwo',
        'relaxation': 0.09894010692485201,
        'relaxation_all': 0.09936780169,
        'charge': 0 ,
        'atoms': 72,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7963, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_3x3x2_qp1" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/SUB_1/1/espresso.pwo',
        'relaxation': 0.09815922277004405,
        'relaxation_all': 0.09911765947,
        'charge': 1,
        'atoms': 72,
        'location': 1,
        'FNV_correction': 0.3507862656,
        'VBM': 8.7963,
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_3x3x2_qp2" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/SUB_1/2/espresso.pwo',
        'relaxation':0.09929489406493616,
        'relaxation_all': 0.1009849354,
        'charge': 2,
        'atoms': 72,
        'location': 1,
        'FNV_correction': 1.155407424,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_3x3x2_qp3" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/SUB_1/3/espresso.pwo',
        'relaxation': 0.10577347672227376,
        'relaxation_all': 0.1130911799,
        'charge': 3,
        'atoms': 72,
        'location': 1,
        'FNV_correction': 2.393028666,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_4x4x3_q0" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/SUB_1/0/espresso.pwo',
        'relaxation':0.10508833036777611,
        'relaxation_all': 0.1043714724,
        'charge': 0,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7939, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_4x4x3_q1" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/SUB_1/1/espresso.pwo',
        'relaxation': 0.10700634717941337,
        'relaxation_all': 0.1070215204,
        'charge': 1,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 0.1929733894,
        'VBM': 8.7939,
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_4x4x3_q2" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/SUB_1/2/espresso.pwo',
        'relaxation':0.11011553872137567,
        'relaxation_all': 0.1114917213,
        'charge': 2,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 0.755731414,
        'VBM': 8.7939,
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_4x4x3_q3" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex32_GaN/supercells/SUB_1/3/espresso.pwo',
        'relaxation':0.11724395013253885,
        'relaxation_all': 0.1206880484,
        'charge': 3,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 1.67717523,
        'VBM': 8.7939, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_5x5x3_q0" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/SUB_1/0/espresso.pwo',
        'relaxation':0.10699017718077196,
        'relaxation_all': 0.1053709566,
        'charge': 0 ,
        'atoms': 300,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_5x5x3_q1" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/SUB_1/1/espresso.pwo',
        'relaxation':0.1092068108144295,
        'relaxation_all': 0.1090180204,
        'charge': 1,
        'atoms': 300,
        'location': 1,
        'FNV_correction': 0.1561638353,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_5x5x3_q2" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/SUB_1/2/espresso.pwo',
        'relaxation':0.11487154825077037,
        'relaxation_all': 0.1158301632,
        'charge': 2,
        'atoms': 300,
        'location': 1,
        'FNV_correction': 0.548900987,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_SUB_5x5x3_q3" : {
        'defect_name':'Ga_N',
        'defect_composition': {'Ga': 1,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex17_GaN/supercells/SUB_1/3/espresso.pwo',
        'relaxation':0.12007046089790266,
        'relaxation_all': 0.122347485,
        'charge': 3,
        'atoms': 300,
        'location': 1,
        'FNV_correction': 1.1976264,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex66_GaN_VAC_2x2x2_qn2" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex66_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex66_222/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.03742891197,
        'relaxation_all': False,
        'charge': -2,
        'atoms': 31,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex66_GaN_VAC_2x2x2_qn1" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex66_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex66_222/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.03660081059,
        'relaxation_all': False,
        'charge': -1,
        'atoms': 31,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex66_GaN_VAC_2x2x2_q0" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex66_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex66_222/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.04520194008,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 31,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_3x3x2_q0" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex40_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex40_GaN/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.04313475262332088,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 71,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_3x3x2_qn1" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex40_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex40_GaN/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.04291277708197279,
        'relaxation_all': False,
        'charge': -1,
        'atoms': 71,
        'location': 1,
        'FNV_correction': 0.5776010334,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_3x3x2_qn2" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex40_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex40_GaN/supercells/VAC_1/-2/espresso.pwo',
        'relaxation':0.04668566820003913,
        'relaxation_all': False,
        'charge': -2,
        'atoms': 71,
        'location': 1,
        'FNV_correction': 1.613221952,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_4x4x3_q0" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex41_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex41_GaN/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.04279888072299876,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 191,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7939, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_4x4x3_qn1" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex41_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex41_GaN/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.044206879423324096,
        'relaxation_all': False,
        'charge': -1,
        'atoms': 191,
        'location': 1,
        'FNV_correction': 0.3338842114,
        'VBM': 8.7939, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_4x4x3_qn2" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex41_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex41_GaN/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.04942072545939133,
        'relaxation_all': False,
        'charge': -2,
        'atoms': 191,
        'location': 1,
        'FNV_correction': 1.045025678,
        'VBM': 8.7939, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_5x5x3_q0" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex44_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex44_GaN/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.042399846575512795,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 299,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_5x5x3_qn1" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex44_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex44_GaN/supercells/VAC_1/-1/espresso.pwo',
        'relaxation': 0.045339373186611416 ,
        'relaxation_all': False,
        'charge': -1,
        'atoms': 299,
        'location': 1,
        'FNV_correction': 0.231283519,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "GaN_VAC_5x5x3_qn2" : {
        'defect_name':'V_Ga',
        'defect_composition': {'Ga': -1,'N':0},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex44_GaN/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_Ga/experiments/ex44_GaN/supercells/VAC_1/-2/espresso.pwo',
        'relaxation': 0.05048407266264777,
        'relaxation_all': False,
        'charge': -2,
        'atoms': 299,
        'location': 1,
        'FNV_correction': 0.7005522334,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex68_SUB_2x2x2_qn1" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/SUB_1/-1/espresso.pwo',
        'relaxation': 0.02660746199,
        'relaxation_all': 0.03586590864,
        'charge': -1 ,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex68_SUB_2x2x2_q0" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/SUB_1/0/espresso.pwo',
        'relaxation': 0.0509526817,
        'relaxation_all': 0.06469371655,
        'charge': 0,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex68_SUB_2x2x2_qp1" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/SUB_1/1/espresso.pwo',
        'relaxation': 0.05585692467,
        'relaxation_all': 0.06602607806,
        'charge': 1 ,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex68_SUB_2x2x2_qp2" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex68_222/supercells/SUB_1/2/espresso.pwo',
        'relaxation': 0.06038739777,
        'relaxation_all': 0.06849348235,
        'charge': 2,
        'atoms': 32,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex56_SUB_3x3x2_qn1" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/SUB_1/-1/espresso.pwo',
        'relaxation': 0.04024647383,
        'relaxation_all': 0.04805040212,
        'charge': -1,
        'atoms': 72,
        'location': 1,
        'FNV_correction': -0.2002045479,
        'VBM': 8.7963, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex56_SUB_3x3x2_qp0" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/SUB_1/0/espresso.pwo',
        'relaxation': 0.021304376904077167,
        'relaxation_all': 0.02069872512,
        'charge': 0 ,
        'atoms': 72,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7963, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex56_SUB_3x3x2_qp1" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/SUB_1/1/espresso.pwo',
        'relaxation': 0.07018179151099804,
        'relaxation_all': 0.08176276301,
        'charge': 1 ,
        'atoms': 72,
        'location': 1,
        'FNV_correction': 0.2509443782,
        'VBM': 8.7963, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex56_SUB_3x3x2_qp2" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex56_332/supercells/SUB_1/2/espresso.pwo',
        'relaxation': 0.10279188807366837,
        'relaxation_all': 0.1000282495,
        'charge': 2,
        'atoms': 72,
        'location': 1,
        'FNV_correction': 1.105319722,
        'VBM': 8.7963, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex57_SUB_4x4x3_qn1" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/SUB_1/-1/espresso.pwo',
        'relaxation': 0.10652286086474996,
        'relaxation_all': 0.1113232951,
        'charge': -1,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 0.2594069755,
        'VBM': 8.7939, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex57_SUB_4x4x3_q0" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/SUB_1/0/espresso.pwo',
        'relaxation':0.10744919455241699,
        'relaxation_all': 0.1119449454,
        'charge': 0,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7939, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex57_SUB_4x4x3_qp1" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/SUB_1/1/espresso.pwo',
        'relaxation':0.10183659000071404,
        'relaxation_all': 0.1100881678,
        'charge': 1,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 0.1377600218,
        'VBM': 8.7939, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex57_SUB_4x4x3_qp2" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex57_443/supercells/SUB_1/2/espresso.pwo',
        'relaxation': 0.1060122866633635,
        'relaxation_all': 0.1170911061,
        'charge': 2,
        'atoms': 192,
        'location': 1,
        'FNV_correction': 0.6530333542,
        'VBM': 8.7939, #energy below Fermi in PRISTINE CELL of given size at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex58_SUB_5x5x3_q0" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex58_553/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex58_553/supercells/SUB_1/0/espresso.pwo',
        'relaxation': 0.1118082641,
        'relaxation_all': 0.1162214888,
        'charge': 0,
        'atoms': 300,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex58_SUB_5x5x3_qn1" : {
        'defect_name':'N_Ga',
        'defect_composition': {'Ga': -1,'N':1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex58_553/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/N_Ga/ex58_553/supercells/SUB_1/-1/espresso.pwo',
        'relaxation': 0.1125676098,
        'relaxation_all': 0.1172571957,
        'charge': -1,
        'atoms': 300,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex69_VAC_2x2x2_q0" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex69_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex69_222/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.01691831847,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 31,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex69_VAC_2x2x2_qp1" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex69_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex69_222/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.01730278932,
        'relaxation_all': False,
        'charge': 1,
        'atoms': 31,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex69_VAC_2x2x2_qp2" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex69_222/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex69_222/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.04852862934,
        'relaxation_all': False,
        'charge': 2,
        'atoms': 31,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7940, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex62_VAC_3x3x2_q0" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex62_332/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex62_332/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.013544693314740442,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 71,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex62_VAC_3x3x2_qp1" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex62_332/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex62_332/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.01377199579846265,
        'relaxation_all': False,
        'charge': 1,
        'atoms': 71,
        'location': 1,
        'FNV_correction': 0.1530359485,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex62_VAC_3x3x2_qp2" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex62_332/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex62_332/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.042200827607343935,
        'relaxation_all': False,
        'charge': 2,
        'atoms': 71,
        'location': 1,
        'FNV_correction': 0.7361336448,
        'VBM': 8.7963, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex63_VAC_4x4x3_q0" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex63_443/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex63_443/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.012605895956325561,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 191,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7939, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex63_VAC_4x4x3_qp1" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex63_443/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex63_443/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.015745551667434455,
        'relaxation_all': False,
        'charge': 1,
        'atoms': 191,
        'location': 1,
        'FNV_correction': 0.1668971247,
        'VBM': 8.7939, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex63_VAC_4x4x3_qp2" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex63_443/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex63_443/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.04293693617297762,
        'relaxation_all': False,
        'charge': 2,
        'atoms': 191,
        'location': 1,
        'FNV_correction': 0.6887858269,
        'VBM': 8.7939, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex64_VAC_5x5x3_q0" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex64_553/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex64_553/supercells/VAC_1/0/espresso.pwo',
        'relaxation': 0.012970071258775294,
        'relaxation_all': False,
        'charge': 0,
        'atoms': 299,
        'location': 1,
        'FNV_correction': 0,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex64_VAC_5x5x3_qp1" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex64_553/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex64_553/supercells/VAC_1/1/espresso.pwo',
        'relaxation': 0.01589924788276179,
        'relaxation_all': False,
        'charge': 1,
        'atoms': 299,
        'location': 1,
        'FNV_correction': 0.108972817,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
    "ex64_VAC_5x5x3_qp2" : {
        'defect_name':'V_N',
        'defect_composition': {'Ga': 0,'N':-1},
        'pristine_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex64_553/supercells/PRISTINE_0/0/espresso.pwo',
        'defect_pwo': f'{beef_charged_defect_dir}/data_files/GaN_mp804/V_N/experiments/ex64_553/supercells/VAC_1/2/espresso.pwo',
        'relaxation': 0.01699962245,
        'relaxation_all': False,
        'charge': 2,
        'atoms': 299,
        'location': 1,
        'FNV_correction': 0.4556409816,
        'VBM': 8.7937, #energy below Fermi at Gammma point
        'pristine_min_bond_length': 1.98352,
    },
}

# %%
# Specify the chemical potential info
#Define the relationships of species
phases = [{
        'type':'primary', #mp-804
        'species' : {
            'Ga': 1,
            'N': 1,
        },
        'dft_output_path': f'{beef_charged_defect_dir}/data_files/GaN_mp804/Ga_N/experiments/ex24_GaN/supercells/PRISTINE_0/0/espresso.pwo',
    },
    {
        'type':'competing', #mp-830
        'species' : {
            'Ga': 1,
            'N': 1,
        },
        'dft_output_path': f'{beef_charged_defect_dir}/data_files/GaN_mp804/chem_pot/GaN_mp830/supercells/PRISTINE_0/0/espresso.pwo',
    },
    {
        'type':'competing', #mp-2853
        'species' : {
            'Ga': 1,
            'N': 1,
        },
        'dft_output_path': f'{beef_charged_defect_dir}/data_files/GaN_mp804/chem_pot/GaN_mp2853/supercells/PRISTINE_0/0/espresso.pwo',
    },
    {
        'type':'competing', #mp-1181864
        'species' : {
            'Ga': 1,
            'N': 1,
        },
        'dft_output_path': f'{beef_charged_defect_dir}/data_files/GaN_mp804/chem_pot/GaN_mp1181864/supercells/PRISTINE_0/0/espresso.pwo',
    },
    {
        'type':'competing', #mp-2646978
        'species' : {
            'Ga': 1,
            'N': 1,
        },
        'dft_output_path': f'{beef_charged_defect_dir}/data_files/GaN_mp804/chem_pot/GaN_mp2646978/supercells/PRISTINE_0/0/espresso.pwo',
    },
    {
        'species': { #mp-142
            'Ga':1,
        },
        'type':'element',
        'dft_output_path': f'{beef_charged_defect_dir}/data_files/GaN_mp804/chem_pot/GaN_mp142/supercells/PRISTINE_0/0/espresso.pwo',
    },
    {
        'species': { #mp-25
            'N':1,
        },
        'type':'element',
        'dft_output_path': f'{beef_charged_defect_dir}/data_files/GaN_mp804/chem_pot/GaN_mp25/supercells/PRISTINE_0/0/espresso.pwo',
    }
]

# %%
#Update to location to store chemical potential data

os.chdir(f"{beef_charged_defect_dir}/data_files/GaN_mp804/analysis")

#Create the CPLAP_with_BEEF object
organizer = Organizer.Organizer(debug_bool=False,grid_spacing = 0.1)

#Add each defined phase
for phase in phases:
    print(f"\nAdding {phase['species']}")
    organizer.addPhase(phase['type'],phase['species'],phase['dft_output_path'])

#Translate the provided DFT results into chemical potential values
#This will be necessary to pass info to CPLAP
organizer.generate_chemical_potentials()

#With the defined dependent species, run CPLAP for each BEEF index
#Once CPLAP completes, fetches boundary inequalilites and intersections
dependent_species = 'Ga'
organizer.organize_CPLAP_interaction(dependent_species)

#Generates a chemical potential grid for each BEEF-index
#Still working in change in chemical potential
organizer.process_all_BEEF_results()

#As function says
#Create persistant files that can be referenced later (without re-running the above)
organizer.generate_final_chemical_potentials()

# %%
import copy

#Read through the qe output. Return a dictionary of raw qe info
def read_qe_output(filename):

    result = {
        'job_done':False,
        'total_energy': False,
        'beef_ensemble':False,
        'atom_dict':False,
    }

    #print(f"Searching for {filename}")
    file_found = True
    #print(f"file_found: {file_found}")

    if file_found == True:

        #print(f"The file '{filename}' has been found! Huzzah!")

        job_complete = False
        total_energy_found = False
        total_energy = 0

        line_nums_atoms = [0,0]
        line_nums_beef_ensemble = [0,0]

        unit_type = ""
        ry_to_eV = 13.6057039763


        with open(filename) as file:

            line_count = 0

            line_info_cart_axes = 'Cartesian axes'
            line_info_crystal_axes = 'Crystallographic axes'
            line_info_beef_ens_header = 'BEEFens 2000 ensemble energies'
            line_info_min_energy = '!    total energy'
            line_info_job_done = 'JOB DONE.'

            #Loop through every line in the output file
            for line in file:

                line_count += 1

                #1. Search for minimum energy
                if line_info_min_energy in line:
                    total_energy_found = True

                    unit = line.split(' ')[-1]
                    #self.debug_obj.debug_log(f"Energy unit: {unit}")

                    total_energy = float(line.split(" ")[-2])
                    #self.debug_obj.debug_log(f"Initial energy value: {total_energy}")

                    if "Ry" in unit:
                        #self.debug_obj.debug_log(f"Energy in Ry!")
                        unit_type = "Ry"
                        total_energy = total_energy*ry_to_eV

                #2. Search for jobe done
                if line_info_job_done in line:
                    job_complete = True
                    #print(f"Job complete found!")

                #3. Search for 'Cartesian axes' header
                if line_info_cart_axes in line:
                    line_nums_atoms[0] = line_count + 3

                #4. Search for 'Crystallographic axes' header
                if line_info_crystal_axes in line:
                    line_nums_atoms[1] = line_count - 2

                #5. Search for 'BEEFens 2000 ensemble energies'
                if line_info_beef_ens_header in line:
                    line_nums_beef_ensemble[0] = line_count + 1
                    line_nums_beef_ensemble[1] = line_count + 2000

            if total_energy_found and job_complete:
                result['job_done'] = True
                result['total_energy'] = total_energy
                #print(f"Total energy = {total_energy} eV!")
            else:
                return result

        #print(f"line_nums_atoms: {line_nums_atoms}")
        #print(f"line_nums_beef_ensemble: {line_nums_beef_ensemble}")

        #Now grab the atoms numbers and beef ensemble
        with open(filename) as file:

            line_count = 0

            atom_dict = {}
            beef_ens = []

            for line in file:
                line_count += 1

                if line_nums_atoms[0] <= line_count <= line_nums_atoms[1]:
                    atom_symbol = line.split()[1]
                    if atom_symbol in atom_dict:
                        atom_dict[atom_symbol] += 1
                    else:
                        atom_dict[atom_symbol] = 1

                if line_nums_beef_ensemble[0] <= line_count <= line_nums_beef_ensemble[1]:
                    raw_energy = float(line.split()[0])
                    clean_energy = 0
                    if unit_type == "Ry":
                        clean_energy = raw_energy*ry_to_eV
                    else:
                        clean_energy = raw_energy
                    beef_ens.append(clean_energy)

                if line_count > line_nums_beef_ensemble[1]:
                    break

            result['beef_ensemble'] = copy.deepcopy(beef_ens)
            result['atom_dict'] = copy.deepcopy(atom_dict)

    return result

# %%
#Get a iterable data structure the chemical potential of the BEEF optimal XC-functional
chemical_potential_optimal = organizer.get_optimal_chemical_potential(find_centroid=True,
                                                                      get_total_cp=True)
chemical_potential_optimal = chemical_potential_optimal[2000]

#Same as above, but for the 2000 'sub-optimal' BEEF XC-functionals
chemical_potential_BEEF = organizer.get_beef_ensemble_chemical_potentials(find_centroid=True,
                                                                          get_total_cp=True)
# Out:
# centroid_estimate: [-393.9260648617449, -3854.5409050418084]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-395.05177375160883, -3859.4156983301655]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-401.3731345950166, -3901.1227059779053]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-396.5689745697636, -3875.1366144477975]
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-391.1568235259588, -3838.2987318241708]
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-398.152241936537, -3889.159186525463]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-400.12516501190237, -3898.298816840755]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-390.15828888298756, -3832.6374697362867]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# centroid_estimate: [-394.3210244545937, -3856.8493346867945]
#
#
#
#
#
#
# File not found for beef {beef_idx}
# centroid_estimate: [-394.108769395943, -3856.206736735618]
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# Generate the 2d array of all meaningful data

import datetime

#Create 2d arrau
table_order = ['defect_name','beef_idx','optimal','centroid','relaxation','relaxation_all','charge','atoms','atoms_per_side','location','dfe','raw_energy','chem_pot','cube_root_of_volume_wrt_min_bond']

all_data = []

add_optimal = True
add_BEEF = True
experiment_filename = "GaN_all_data.csv"

total_systems = len(defect_systems)
count = 0

GaN_skip_indeces = [132,907,1215,1468,1692]

for defect_system in defect_systems:

    count += 1
    print(f"Defect System: {defect_system} -- [{count}/{total_systems}]")
    start = datetime.datetime.now()

    defect_composition = defect_systems[defect_system]['defect_composition']

    pristine_result = read_qe_output(defect_systems[defect_system]["pristine_pwo"])
    defect_result = read_qe_output(defect_systems[defect_system]["defect_pwo"])

    pristine_number_of_atoms = pristine_result['atom_dict']['Ga']
    pristine_number_of_atoms += pristine_result['atom_dict']['N']

    pristine_ase = ase_read(defect_systems[defect_system]["pristine_pwo"])
    pristine_pymatgen = AseAtomsAdaptor.get_structure(atoms = pristine_ase)
    cube_root_of_volume = ((pristine_pymatgen.volume)**(1/3)) #pymat api gives volume in Angstrom^3
    cube_root_of_volume_wrt_min_bond = cube_root_of_volume/(defect_systems[defect_system]['pristine_min_bond_length'])

    entry_template = np.zeros(len(table_order),dtype=object)
    entry_template[table_order.index('defect_name')] = defect_systems[defect_system]['defect_name']
    entry_template[table_order.index('charge')] = defect_systems[defect_system]['charge']
    entry_template[table_order.index('atoms')] = defect_systems[defect_system]['atoms']
    entry_template[table_order.index('atoms_per_side')] = (pristine_number_of_atoms)**(1/3)
    entry_template[table_order.index('location')] = defect_systems[defect_system]['location']
    entry_template[table_order.index('centroid')] = False
    entry_template[table_order.index('optimal')] = False
    entry_template[table_order.index('cube_root_of_volume_wrt_min_bond')] = cube_root_of_volume_wrt_min_bond

    #Relaxation (Angstroms, NOT normalized)
    entry_template[table_order.index('relaxation')] = defect_systems[defect_system]['relaxation']
    if(defect_systems[defect_system]['relaxation_all'] == False):
        entry_template[table_order.index('relaxation_all')] = defect_systems[defect_system]['relaxation']
    else:
        entry_template[table_order.index('relaxation_all')] = defect_systems[defect_system]['relaxation_all']

    if(add_optimal):
        #First iterate through the 'optimal' chemical potential
        entry_template[table_order.index('optimal')] = True
        entry_template[table_order.index('beef_idx')] = 2000

        raw_energy = defect_result['total_energy'] - pristine_result['total_energy']
        entry_template[table_order.index('raw_energy')] = raw_energy
        raw_energy += defect_systems[defect_system]['FNV_correction']

        for chem_pot_coord in chemical_potential_optimal:
            #print(f"Chem Pot coordinate: {chem_pot_coord}")

            new_row = copy.copy(entry_template)

            #Calculate and add defect formation energy
            #print(f"Chemical Potenital")
            chem_energy = 0
            for species in defect_composition:
                chem_energy += (chem_pot_coord[species]*defect_composition[species])
            new_row[table_order.index('chem_pot')] = chem_energy
            new_row[table_order.index('raw_energy')] = raw_energy

            electron_energy_correction = defect_systems[defect_system]['charge'] * defect_systems[defect_system]['VBM']

            dfe = raw_energy - chem_energy + electron_energy_correction
            #print(f"raw energy: {raw_energy}")
            #print(f"chem pot: {chem_energy}")
            #print(f"dfe: {dfe}")
            new_row[table_order.index('dfe')] = dfe

            #Update centroid
            if(chem_pot_coord['centroid'] == True):
                new_row[table_order.index('centroid')] = True

            #all_data = np.insert(all_data,0, new_row, axis=0)
            all_data.append(new_row)

    if(add_BEEF):
        #Next iterate through the BEEF ensemble
        entry_template[table_order.index('optimal')] = False

        #Next iterate through the BEEF ensemble
        for beef_idx in range(0,2000):

            #Ignore bad indeces
            if beef_idx in GaN_skip_indeces:
                continue

            chem_pot_of_beef_idx = chemical_potential_BEEF[beef_idx]
            if not chem_pot_of_beef_idx:
                #print(f"Beef #{beef_idx} is empty.")
                continue

            entry_template[table_order.index('beef_idx')] = beef_idx

            pristine_energy = (pristine_result['total_energy'] + pristine_result['beef_ensemble'][beef_idx])
            defect_energy = (defect_result['total_energy'] + defect_result['beef_ensemble'][beef_idx])
            raw_energy = (defect_energy - pristine_energy)
            entry_template[table_order.index('raw_energy')] = raw_energy
            raw_energy += defect_systems[defect_system]['FNV_correction']

            for chem_pot_coord in chem_pot_of_beef_idx:
                new_row = copy.copy(entry_template)

                #Calculate and add defect formation energy
                chem_energy = 0

                for species in defect_composition:
                    chem_energy += (chem_pot_coord[species]*defect_composition[species])
                new_row[table_order.index('chem_pot')] = chem_energy

                electron_energy_correction = defect_systems[defect_system]['charge'] * defect_systems[defect_system]['VBM']

                dfe = raw_energy - chem_energy + electron_energy_correction
                new_row[table_order.index('dfe')] = dfe

                #Update centroid
                if(chem_pot_coord['centroid'] == True):
                    new_row[table_order.index('centroid')] = True

                all_data.append(new_row)

    stop = datetime.datetime.now()
    print(f"Duration: {stop-start}")

os.chdir(f'{beef_charged_defect_dir}/data_files/GaN_mp804/analysis')

import pandas as pd
pd_all_data = pd.DataFrame(all_data)
pd_all_data.columns = table_order
pd_all_data.to_csv(experiment_filename)
# Out:
# Defect System: GaN_SUB_2x2x2_qp0 -- [1/54]
# Duration: 0:00:00.090042
# Defect System: GaN_SUB_2x2x2_qp1 -- [2/54]
# Duration: 0:00:00.047083
# Defect System: GaN_SUB_2x2x2_qp2 -- [3/54]
# Duration: 0:00:00.045966
# Defect System: GaN_SUB_2x2x2_qp3 -- [4/54]
# Duration: 0:00:00.050738
# Defect System: GaN_SUB_3x3x2_qp0 -- [5/54]
# Duration: 0:00:00.054054
# Defect System: GaN_SUB_3x3x2_qp1 -- [6/54]
# Duration: 0:00:00.052140
# Defect System: GaN_SUB_3x3x2_qp2 -- [7/54]
# Duration: 0:00:00.048429
# Defect System: GaN_SUB_3x3x2_qp3 -- [8/54]
# Duration: 0:00:00.056212
# Defect System: GaN_SUB_4x4x3_q0 -- [9/54]
# Duration: 0:00:00.065873
# Defect System: GaN_SUB_4x4x3_q1 -- [10/54]
# Duration: 0:00:00.053809
# Defect System: GaN_SUB_4x4x3_q2 -- [11/54]
# Duration: 0:00:00.080113
# Defect System: GaN_SUB_4x4x3_q3 -- [12/54]
# Duration: 0:00:00.058852
# Defect System: GaN_SUB_5x5x3_q0 -- [13/54]
# Duration: 0:00:00.063097
# Defect System: GaN_SUB_5x5x3_q1 -- [14/54]
# ...
